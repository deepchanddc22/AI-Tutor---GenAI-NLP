# %%
import streamlit as st
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os
from langchain_google_genai import GoogleGenerativeAIEmbeddings
import google.generativeai as genai
from langchain.vectorstores import FAISS
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains.question_answering import load_qa_chain
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv
import random

load_dotenv()
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
llm = ChatGoogleGenerativeAI(model="gemini-pro")

context = '''The correlation plot is based on pearson correlation, from this graph we can infer
the distance is highly correlated to battery temperature. So In order to find if it is
negatively correlated or positively correlated we plotted a bar graph Figure 6.2
which shows the relationship between battery temperature and distance which is
positively correlated.'''
result = llm.invoke(f"create mcq from this paragraph : {context}")
print(result.content)
# Out:
# **MCQ:**
#
# **1. Which type of correlation is used in the correlation plot?**
#
# (A) Spearman's rank correlation
# (B) Pearson correlation
# (C) Kendall's tau correlation
# (D) Biserial correlation
#
# **2. According to the paragraph, which variables are highly correlated?**
#
# (A) Battery temperature and distance
# (B) Distance and voltage
# (C) Battery capacity and distance
# (D) Distance and charge time
#
# **3. What type of graph was used to determine the direction of the correlation between battery temperature and distance?**
#
# (A) Scatter plot
# (B) Bar graph
# (C) Line graph
# (D) Pie chart
#
# **Answer Key:**
#
# 1. B
# 2. A
# 3. B

# %%
import streamlit as st
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os
from langchain_google_genai import GoogleGenerativeAIEmbeddings
import google.generativeai as genai
from langchain.vectorstores import FAISS
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains.question_answering import load_qa_chain
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv
import random

# Load environment variables
load_dotenv()

# Configure Google Generative AI
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
llm = ChatGoogleGenerativeAI(model="gemini-pro")

import streamlit as st
import os
import json
import google.generativeai as genai





def get_question():
    model = genai.GenerativeModel('gemini-pro')
    response = model.generate_content("generate questions on basic science. provide the response as a json containing question, choices, correct_answer, and explanation",
                                       generation_config=genai.types.GenerationConfig(temperature=0.5))
    
    return (response.text)
# Out:
# ```json
# [
#   {
#     "question": "Which of the following is NOT a state of matter?",
#     "choices": [
#       "Solid",
#       "Liquid",
#       "Gas",
#       "Plasma",
#       "Energy"
#     ],
#     "correct_answer": "Energy",
#     "explanation": "Energy is not a state of matter. The three states of matter are solid, liquid, and gas. Plasma is a fourth state of matter that is created when a gas is heated to a very high temperature."
#   },
#   {
#     "question": "What is the SI unit of force?",
#     "choices": [
#       "Newton",
#       "Joule",
#       "Watt",
#       "Pascal",
#       "Ampere"
#     ],
#     "correct_answer": "Newton",
#     "explanation": "The SI unit of force is the newton (N). It is named after Sir Isaac Newton, who developed the laws of motion."
#   },
#   {
#     "question": "Which of the following is a conductor of electricity?",
#     "choices": [
#       "Metal",
#       "Plastic",
#       "Wood",
#       "Rubber",
#       "Water"
#     ],
#     "correct_answer": "Metal",
#     "explanation": "Metals are good conductors of electricity because they have free electrons that can move easily. Plastic, wood, rubber, and water are poor conductors of electricity because they do not have many free electrons."
#   },
#   {
#     "question": "What is the process by which plants convert sunlight into energy called?",
#     "choices": [
#       "Photosynthesis",
#       "Respiration",
#       "Evaporation",
#       "Condensation",
#       "Transpiration"
#     ],
#     "correct_answer": "Photosynthesis",
#     "explanation": "Photosynthesis is the process by which plants use sunlight, water, and carbon dioxide to create glucose (sugar) and oxygen. Glucose is the energy that plants need to grow and survive."
#   },
#   {
#     "question": "Which of the following is a renewable energy source?",
#     "choices": [
#       "Fossil fuels",
#       "Solar energy",
#       "Wind energy",
#       "Nuclear energy",
#       "Hydroelectric energy"
#     ],
#     "correct_answer": "Solar energy",
#     "explanation": "Renewable energy sources are those that can be replenished naturally. Solar energy, wind energy, and hydroelectric energy are all renewable energy sources. Fossil fuels and nuclear energy are non-renewable energy sources."
#   }
# ]
# ```

# %%
import streamlit as st
import os
import google.generativeai as genai
import json
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

# Load environment variables
load_dotenv()

# Configure Google Generative AI
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
llm = ChatGoogleGenerativeAI(model="gemini-pro")

def get_question():
    model = genai.GenerativeModel('gemini-pro')
    response = model.generate_content('''generate questions on basic science. provide the response as a json [
    {
        "question": "What is the primary goal of artificial intelligence?",
        "information": "This field of computer science aims to create systems capable of performing tasks that would typically require human intelligence.",
        "options": ["To simulate human intelligence", "To enhance computer speed", "To replace human jobs", "To improve data storage"],
        "answer": "To simulate human intelligence"
    },
    {
        "question": "What is 'machine learning' in the context of artificial intelligence?",
        "information": "This is a subset of artificial intelligence that involves the creation of systems that can learn from and make decisions based on data.",
        "options": ["A new programming language", "A data processing method", "A subset of artificial intelligence", "A type of computer hardware"],
        "answer": "A subset of artificial intelligence"
    }''',
                                       generation_config=genai.types.GenerationConfig(temperature=0.5))
    print(response.text)
    filename = "quiz_data.json"

    # Convert the text to a dictionary
    data = json.loads(response.text)

    # Save data to a JSON file
    with open(filename, "a") as json_file:
         json.dump(data, json_file, indent=2)

get_question()
# Out:
# [
#   {
#     "question": "What is the process by which plants convert sunlight into energy called?",
#     "information": "This process is essential for the survival of plants and is responsible for the production of oxygen.",
#     "options": ["Photosynthesis", "Respiration", "Transpiration", "Fermentation"],
#     "answer": "Photosynthesis"
#   },
#   {
#     "question": "What is the name of the largest organ in the human body?",
#     "information": "This organ is responsible for filtering blood and removing waste products.",
#     "options": ["Liver", "Skin", "Lungs", "Brain"],
#     "answer": "Skin"
#   },
#   {
#     "question": "What is the name of the force that attracts objects towards each other?",
#     "information": "This force is responsible for keeping planets in orbit around the sun.",
#     "options": ["Gravity", "Magnetism", "Electromagnetism", "Friction"],
#     "answer": "Gravity"
#   },
#   {
#     "question": "What is the name of the chemical element with the symbol Au?",
#     "information": "This element is known for its yellow color and is often used in jewelry.",
#     "options": ["Gold", "Silver", "Copper", "Iron"],
#     "answer": "Gold"
#   },
#   {
#     "question": "What is the name of the largest planet in our solar system?",
#     "information": "This planet is known for its distinctive red color and is home to the Great Red Spot.",
#     "options": ["Jupiter", "Saturn", "Uranus", "Neptune"],
#     "answer": "Jupiter"
#   }
# ]
